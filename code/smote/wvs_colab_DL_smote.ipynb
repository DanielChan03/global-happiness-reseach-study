# %% [markdown]
# ## DL Model Training - SMOTE

# %% [markdown]
# #### Import libraries

# %%
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader
import numpy as np, random
from google.colab import drive
drive.mount('/content/drive')

# 1. Set seeds
seed = 42
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
torch.cuda.manual_seed_all(seed)

# 2. Deterministic settings
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
# Out:
# Mounted at /content/drive

# %% [markdown]
# #### Load Training Sets

# %%
X_train_final = pd.read_csv("/content/drive/My Drive/Colab Notebooks/data/X_train_final_smote.csv")
X_test_final = pd.read_csv("/content/drive/My Drive/Colab Notebooks/data/X_test_final.csv")
X_val_final = pd.read_csv("/content/drive/My Drive/Colab Notebooks/data/X_val_final.csv")

y_train_final = pd.read_csv("/content/drive/My Drive/Colab Notebooks/data/y_train_final_smote.csv")
y_test_final = pd.read_csv("/content/drive/My Drive/Colab Notebooks/data/y_test_final.csv")
y_val_final = pd.read_csv("/content/drive/My Drive/Colab Notebooks/data/y_val_final.csv")

# %%
# --- 1. Convert final datasets to PyTorch tensors ---
X_train_tensor = torch.tensor(X_train_final.values, dtype=torch.float32)
y_train_tensor = torch.tensor(y_train_final.values.reshape(-1,1), dtype=torch.float32)

X_val_tensor = torch.tensor(X_val_final.values, dtype=torch.float32)
y_val_tensor = torch.tensor(y_val_final.values.reshape(-1, 1), dtype=torch.float32)

X_test_tensor = torch.tensor(X_test_final.values, dtype=torch.float32)
y_test_tensor = torch.tensor(y_test_final.values.reshape(-1, 1), dtype=torch.float32)

# %%
# --- 2. Create PyTorch datasets and dataloaders ---
train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
val_dataset = TensorDataset(X_val_tensor, y_val_tensor)
test_dataset = TensorDataset(X_test_tensor, y_test_tensor)

batch_size = 64
g = torch.Generator()
g.manual_seed(seed)  # fix seed for DataLoader shuffling

train_loader = DataLoader(
    train_dataset,
    batch_size=batch_size,
    shuffle=True,           # still shuffle for training
    num_workers=0,          # avoid parallel non-determinism
    generator=g
)

val_loader = DataLoader(
    val_dataset,
    batch_size=batch_size,
    shuffle=False,
    num_workers=0
)

test_loader = DataLoader(
    test_dataset,
    batch_size=batch_size,
    shuffle=False,
    num_workers=0
)

# %%
# --- 3. Define a simple MLP model ---
class SimpleMLP(nn.Module):
    def __init__(self, input_dim, hidden_sizes=[64,32], dropout=0.0):  # MODIFIED
        super(SimpleMLP, self).__init__()
        layers = []
        last_dim = input_dim
        for h in hidden_sizes:
            layers.append(nn.Linear(last_dim, h))
            layers.append(nn.ReLU())
            if dropout > 0.0:  # ADDED
                layers.append(nn.Dropout(dropout))
            last_dim = h
        layers.append(nn.Linear(last_dim, 1))  # output for binary classification
        self.model = nn.Sequential(*layers)

    def forward(self, x):
        return self.model(x)

input_dim = X_train_final.shape[1]
model = SimpleMLP(input_dim)

# --- 3b. Deep & Cross Network (DCN) ---
class CrossLayer(nn.Module):
    def __init__(self, input_dim):
        super(CrossLayer, self).__init__()
        self.weight = nn.Parameter(torch.randn(input_dim, 1))
        self.bias = nn.Parameter(torch.randn(input_dim))

    def forward(self, x):
        x0 = x                              # [batch, D]
        xw = torch.matmul(x, self.weight)   # [batch, 1]
        x_cross = x0 * xw + self.bias       # [batch, D]
        return x_cross


class DCN(nn.Module):
    def __init__(self, input_dim, deep_hidden=[64,32],dropout=0.0):
        super(DCN, self).__init__()
        self.cross = CrossLayer(input_dim)
        layers = []
        last_dim = input_dim
        for h in deep_hidden:
            layers.append(nn.Linear(last_dim, h))
            layers.append(nn.ReLU())
            if dropout > 0.0:  # ADDED
                layers.append(nn.Dropout(dropout))
            last_dim = h
        layers.append(nn.Linear(last_dim, 1))
        self.deep = nn.Sequential(*layers)

    def forward(self, x):
        x_cross = self.cross(x)              # [batch, D] now
        x_deep = self.deep(x)                # deep network outputs [batch, 1]
        combined = x_cross.sum(dim=1, keepdim=True) + x_deep
        return combined

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from sklearn.metrics import roc_auc_score, matthews_corrcoef
import copy

# ---------------- Evaluate function ----------------
def evaluate_and_report(model, loader, criterion, device):
    """
    Evaluate a model on a given loader.
    Returns:
        - loss (average over batches)
        - accuracy
        - AUC score
    """
    model.eval()
    all_labels = []
    all_outputs = []
    all_preds = []

    total_loss = 0.0
    total_samples = 0
    correct = 0

    with torch.no_grad():
        for X_batch, y_batch in loader:
            X_batch, y_batch = X_batch.to(device), y_batch.to(device)
            y_batch = y_batch.float().view(-1, 1)

            outputs = model(X_batch)
            loss = criterion(outputs, y_batch)
            total_loss += loss.item() * y_batch.size(0)

            preds = (torch.sigmoid(outputs) > 0.5).float()
            correct += (preds == y_batch).sum().item()
            total_samples += y_batch.size(0)

            all_labels.append(y_batch.cpu())
            all_outputs.append(torch.sigmoid(outputs).cpu())
            all_preds.append(preds.cpu())

    avg_loss = total_loss / total_samples
    acc = correct / total_samples

    all_labels = torch.cat(all_labels).numpy()
    all_outputs = torch.cat(all_outputs).numpy()
    all_preds = torch.cat(all_preds).numpy().ravel()

    auc = roc_auc_score(all_labels, all_outputs)
    mcc = matthews_corrcoef(all_labels, all_preds)

    return {"loss": avg_loss, "acc": acc, "auc": auc, "mcc": mcc}

# ---------------- Train model ----------------
def train_model(
    model,
    train_loader,
    val_loader,
    test_loader=None,           # optional test loader
    epochs=100,
    lr=0.001,
    weight_decay=1e-4,
    patience=10,
    hyperparams={}
):
    """
    Train a PyTorch model with early stopping based on validation loss,
    tracking train/validation accuracy and AUC.
    Final test accuracy is evaluated after training.
    """
    model_name = model.__class__.__name__
    print(f"Training {model_name}...")

    criterion = nn.BCEWithLogitsLoss()
    optimizer = optim.AdamW(model.parameters(), lr=lr, weight_decay=weight_decay)

    best_val_loss = float('inf')
    best_val_acc = 0.0
    best_val_auc = 0.0
    best_hyperparams = None
    best_model_state = None
    wait = 0
    device = next(model.parameters()).device

    for epoch in range(epochs):
        # ---------------- Training ----------------
        model.train()
        train_losses = []
        correct_train = 0
        total_train = 0

        for X_batch, y_batch in train_loader:
            X_batch, y_batch = X_batch.to(device), y_batch.to(device)
            y_batch = y_batch.float().view(-1, 1)

            optimizer.zero_grad()
            outputs = model(X_batch)
            loss = criterion(outputs, y_batch)
            loss.backward()
            optimizer.step()
            train_losses.append(loss.item())

            preds = (torch.sigmoid(outputs) > 0.5).float()
            correct_train += (preds == y_batch).sum().item()
            total_train += y_batch.size(0)

        avg_train_loss = sum(train_losses)/len(train_losses)
        train_acc = correct_train / total_train

        # ---------------- Validation ----------------
        val_metrics = evaluate_and_report(model, val_loader, criterion, device)
        val_loss = val_metrics["loss"]
        val_acc = val_metrics["acc"]
        val_auc = val_metrics["auc"]
        val_mcc = val_metrics["mcc"]

        # ---------------- Early stopping ----------------
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            best_val_acc = val_acc
            best_val_auc = val_auc
            best_val_mcc = val_mcc
            best_model_state = copy.deepcopy(model.state_dict())
            best_hyperparams = hyperparams
            wait = 0
        else:
            wait += 1
            if wait >= patience:
                print(f"Early stopping at epoch {epoch+1}")
                break

        # ---------------- Print metrics ----------------
        if (epoch + 1) % 10 == 0 or epoch == epochs - 1:
            print(f"[{model_name}] Epoch {epoch+1}/{epochs} | "
                  f"Train Loss: {avg_train_loss:.4f} | Val Loss: {val_loss:.4f} | "
                  f"Train Acc: {train_acc:.4f} | Val Acc: {val_acc:.4f} | Val AUC: {val_auc:.4f} | Val MCC: {val_mcc:.4f}")

    # ---------------- Load best model ----------------
    model.load_state_dict(best_model_state)
    model = model.to(device)

    # ---------------- Final test evaluation ----------------
    if test_loader is not None:
        test_metrics = evaluate_and_report(model, test_loader, criterion, device)
        test_acc = test_metrics["acc"]
        test_mcc = test_metrics["mcc"]
    else:
        test_acc = None
        test_mcc = None

    # ---------------- Summary ----------------
    print("-"*10)
    print(f"Best Val Acc: {best_val_acc:.4f} | Val AUC: {best_val_auc:.4f}")
    print(f"Best Hyperparameters: {best_hyperparams}")
    if test_acc is not None:
        print(f"Final Test Accuracy: {test_acc:.4f}")
    print("-"*20)

    # ---------------- Return metrics ----------------
    return {
        "model": model,
        "best_val_acc": best_val_acc,
        "best_val_auc": best_val_auc,
        "test_acc": test_acc,
        "test_mcc": test_mcc,
        "best_hyperparams": best_hyperparams
    }

# %% [markdown]
# ### Hyperparameter Tuning

# %%
import itertools

# ---------------- Hyperparameter ranges ----------------
hidden_sizes_options = [[64, 32], [128, 64], [32, 16]]
dropout_options = [0.0, 0.1, 0.2]
lr_options = [1e-3, 3e-4, 1e-4]
weight_decay_options = [1e-4, 1e-3, 1e-2]

# ---------------- Generate all combinations ----------------
configs = []
for hs, do, lr, wd in itertools.product(hidden_sizes_options,
                                        dropout_options,
                                        lr_options,
                                        weight_decay_options):
    configs.append({
        "hidden_sizes": hs,
        "dropout": do,
        "lr": lr,
        "weight_decay": wd
    })

print(f"Total hyperparameter combinations: {len(configs)}")
# Out:
# Total hyperparameter combinations: 81

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)

hyperparameter_tuned_results = []
models_to_train = [                 # Hyperparameter tuning, 10 epochs only
    ("SimpleMLP", SimpleMLP, 10),
    ("DCN", DCN, 10)
]

for model_name, model_class, epochs in models_to_train:

    for cfg in configs:
        # --- Map the config keys based on model class ---
        if model_class == SimpleMLP:
            model = model_class(
                input_dim=X_train_final.shape[1],
                hidden_sizes=cfg.get("hidden_sizes", None),
                dropout=cfg["dropout"]
            )
        elif model_class == DCN:
            model = model_class(
                input_dim=X_train_final.shape[1],
                deep_hidden=cfg.get("hidden_sizes", None),  # map hidden_sizes -> deep_hidden
                dropout=cfg["dropout"]
            )
        else:
            raise ValueError(f"Unknown model class: {model_class}")

        model = model.to(device)

        result = train_model(
            model,
            train_loader,
            val_loader,
            test_loader,
            epochs=epochs,
            lr=cfg["lr"],
            weight_decay=cfg["weight_decay"],
            patience=10,
            hyperparams=cfg
        )
        result["model_name"] = model_name
        hyperparameter_tuned_results.append(result)
# Out:
# Using device: cuda
# Training SimpleMLP...
# [SimpleMLP] Epoch 10/10 | Train Loss: 0.3325 | Val Loss: 0.4233 | Train Acc: 0.8556 | Val Acc: 0.8125 | Val AUC: 0.8017 | Val MCC: 0.3622
# ----------
# Best Val Acc: 0.8118 | Val AUC: 0.8063
# Best Hyperparameters: {'hidden_sizes': [64, 32], 'dropout': 0.0, 'lr': 0.001, 'weight_decay': 0.0001}
# Final Test Accuracy: 0.8089
# --------------------
# Training SimpleMLP...
# [SimpleMLP] Epoch 10/10 | Train Loss: 0.3242 | Val Loss: 0.4655 | Train Acc: 0.8597 | Val Acc: 0.7857 | Val AUC: 0.8024 | Val MCC: 0.3562
# ----------
# Best Val Acc: 0.8537 | Val AUC: 0.8236
# Best Hyperparameters: {'hidden_sizes': [64, 32], 'dropout': 0.0, 'lr': 0.001, 'weight_decay': 0.001}
# Final Test Accuracy: 0.8530
# --------------------
# Training SimpleMLP...
# [SimpleMLP] Epoch 10/10 | Train Loss: 0.3318 | Val Loss: 0.4186 | Train Acc: 0.8558 | Val Acc: 0.8111 | Val AUC: 0.7995 | Val MCC: 0.3538
# ----------
# Best Val Acc: 0.8246 | Val AUC: 0.8097
# Best Hyperparameters: {'hidden_sizes': [64, 32], 'dropout': 0.0, 'lr': 0.001, 'weight_decay': 0.01}
# Final Test Accuracy: 0.8198
# --------------------
# Training SimpleMLP...
# [SimpleMLP] Epoch 10/10 | Train Loss: 0.3870 | Val Loss: 0.4194 | Train Acc: 0.8275 | Val Acc: 0.8064 | Val AUC: 0.8139 | Val MCC: 0.3808
# ----------
# Best Val Acc: 0.8085 | Val AUC: 0.8239
# Best Hyperparameters: {'hidden_sizes': [64, 32], 'dropout': 0.0, 'lr': 0.0003, 'weight_decay': 0.0001}
# Final Test Accuracy: 0.7970
# --------------------
# Training SimpleMLP...
# [SimpleMLP] Epoch 10/10 | Train Loss: 0.3793 | Val Loss: 0.4230 | Train Acc: 0.8319 | Val Acc: 0.8058 | Val AUC: 0.8136 | Val MCC: 0.3736
# ----------
# Best Val Acc: 0.8194 | Val AUC: 0.8192
# Best Hyperparameters: {'hidden_sizes': [64, 32], 'dropout': 0.0, 'lr': 0.0003, 'weight_decay': 0.001}
# Final Test Accuracy: 0.8200
# --------------------
# Training SimpleMLP...
# [SimpleMLP] Epoch 10/10 | Train Loss: 0.3971 | Val Loss: 0.4338 | Train Acc: 0.8210 | Val Acc: 0.8002 | Val AUC: 0.8174 | Val MCC: 0.3877
# ----------
# Best Val Acc: 0.8285 | Val AUC: 0.8313
# Best Hyperparameters: {'hidden_sizes': [64, 32], 'dropout': 0.0, 'lr': 0.0003, 'weight_decay': 0.01}
# Final Test Accuracy: 0.8227
# --------------------
# Training SimpleMLP...
# [SimpleMLP] Epoch 10/10 | Train Loss: 0.4421 | Val Loss: 0.4831 | Train Acc: 0.7961 | Val Acc: 0.7666 | Val AUC: 0.8304 | Val MCC: 0.3888
# ----------
# Best Val Acc: 0.7891 | Val AUC: 0.8333
# Best Hyperparameters: {'hidden_sizes': [64, 32], 'dropout': 0.0, 'lr': 0.0001, 'weight_decay': 0.0001}
# Final Test Accuracy: 0.7840
# --------------------
# Training SimpleMLP...
# [SimpleMLP] Epoch 10/10 | Train Loss: 0.4367 | Val Loss: 0.4393 | Train Acc: 0.7996 | Val Acc: 0.7912 | Val AUC: 0.8280 | Val MCC: 0.3902
# ----------
# Best Val Acc: 0.8026 | Val AUC: 0.8323
# Best Hyperparameters: {'hidden_sizes': [64, 32], 'dropout': 0.0, 'lr': 0.0001, 'weight_decay': 0.001}
# Final Test Accuracy: 0.7951
# --------------------
# Training SimpleMLP...
# [SimpleMLP] Epoch 10/10 | Train Loss: 0.4390 | Val Loss: 0.4827 | Train Acc: 0.7971 | Val Acc: 0.7659 | Val AUC: 0.8302 | Val MCC: 0.3848
# ----------
# Best Val Acc: 0.7917 | Val AUC: 0.8349
# Best Hyperparameters: {'hidden_sizes': [64, 32], 'dropout': 0.0, 'lr': 0.0001, 'weight_decay': 0.01}
# Final Test Accuracy: 0.
# --------------------
# Training DCN...
# [DCN] Epoch 10/10 | Train Loss: 13.2546 | Val Loss: 6.7135 | Train Acc: 0.6957 | Val Acc: 0.7731 | Val AUC: 0.7763 | Val MCC: 0.3563
# ----------
# Best Val Acc: 0.7731 | Val AUC: 0.7763
# Best Hyperparameters: {'hidden_sizes': [64, 32], 'dropout': 0.1, 'lr': 0.0003, 'weight_decay': 0.001}
# Final Test Accuracy: 0.7705
# --------------------
# Training DCN...
# [DCN] Epoch 10/10 | Train Loss: 8.1338 | Val Loss: 5.1504 | Train Acc: 0.7037 | Val Acc: 0.7268 | Val AUC: 0.7904 | Val MCC: 0.3425
# ----------
# Best Val Acc: 0.7768 | Val AUC: 0.7856
# Best Hyperparameters: {'hidden_sizes': [64, 32], 'dropout': 0.1, 'lr': 0.0003, 'weight_decay': 0.01}
# Final Test Accuracy: 0.7720
# --------------------
# Training DCN...
# [DCN] Epoch 10/10 | Train Loss: 25.3702 | Val Loss: 18.4831 | Train Acc: 0.7010 | Val Acc: 0.7402 | Val AUC: 0.7676 | Val MCC: 0.3409
# ----------
# Best Val Acc: 0.7402 | Val AUC: 0.7676
# Best Hyperparameters: {'hidden_sizes': [64, 32], 'dropout': 0.1, 'lr': 0.0001, 'weight_decay': 0.0001}
# Final Test Accuracy: 0.7303
# --------------------
# Training DCN...
# [DCN] Epoch 10/10 | Train Loss: 24.8605 | Val Loss: 15.4892 | Train Acc: 0.6726 | Val Acc: 0.7366 | Val AUC: 0.7473 | Val MCC: 0.3175
# ----------
# Best Val Acc: 0.7366 | Val AUC: 0.7473
# Best Hyperparameters: {'hidden_sizes': [64, 32], 'dropout': 0.1, 'lr': 0.0001, 'weight_decay': 0.001}
# Final Test Accuracy: 0.7309
# --------------------
# Training DCN...
# [DCN] Epoch 10/10 | Train Loss: 22.2955 | Val Loss: 12.4717 | Train Acc: 0.6820 | Val Acc: 0.7608 | Val AUC: 0.7468 | Val MCC: 0.3270
# ----------
# Best Val Acc: 0.7608 | Val AUC: 0.7468
# Best Hyperparameters: {'hidden_sizes': [64, 32], 'dropout': 0.1, 'lr': 0.0001, 'weight_decay': 0.01}
# Final Test Accuracy: 0.7605
# --------------------
# Training DCN...
# [DCN] Epoch 10/10 | Train Loss: 6.1642 | Val Loss: 3.7201 | Train Acc: 0.7193 | Val Acc: 0.7488 | Val AUC: 0.8078 | Val MCC: 0.3650
# ----------
# Best Val Acc: 0.7897 | Val AUC: 0.8018
# Best Hyperparameters: {'hidden_sizes': [64, 32], 'dropout': 0.2, 'lr': 0.001, 'weight_decay': 0.0001}
# Final Test Accuracy: 0.7868
# --------------------
# Training DCN...
# [DCN] Epoch 10/10 | Train Loss: 4.8922 | Val Loss: 3.7612 | Train Acc: 0.7337 | Val Acc: 0.7055 | Val AUC: 0.8010 | Val MCC: 0.3329
# ----------
# Best Val Acc: 0.7055 | Val AUC: 0.8010
# Best Hyperparameters: {'hidden_sizes': [64, 32], 'dropout': 0.2, 'lr': 0.001, 'weight_decay': 0.001}
# Final Test Accuracy: 0.6948
# --------------------
# Training DCN...
# [DCN] Epoch 10/10 | Train Loss: 3.9616 | Val Loss: 1.8693 | Train Acc: 0.7202 | Val Acc: 0.7912 | Val AUC: 0.8050 | Val MCC: 0.3780
# ----------
# Best Val Acc: 0.7912 | Val AUC: 0.8050
# Best Hyperparameters: {'hidden_sizes': [64, 32], 'dropout': 0.2, 'lr': 0.001, 'weight_decay': 0.01}
# Final Test Accuracy: 0.7875
# --------------------
# Training DCN...
# [DCN] Epoch 10/10 | Train Loss: 10.8984 | Val Loss: 4.9129 | Train Acc: 0.6989 | Val Acc: 0.7692 | Val AUC: 0.7979 | Val MCC: 0.3760
# ----------
# Best Val Acc: 0.7692 | Val AUC: 0.7979
# Best Hyperparameters: {'hidden_sizes': [64, 32], 'dropout': 0.2, 'lr': 0.0003, 'weight_decay': 0.0001}
# Final Test Accuracy: 0.7610
# --------------------
# Training DCN...
# [DCN] Epoch 10/10 | Train Loss: 11.2161 | Val Loss: 5.7907 | Train Acc: 0.6908 | Val Acc: 0.7554 | Val AUC: 0.7944 | Val MCC: 0.3637
# ----------
# Best Val Acc: 0.7554 | Val AUC: 0.7944
# Best Hyperparameters: {'hidden_sizes': [64, 32], 'dropout': 0.2, 'lr': 0.0003, 'weight_decay': 0.001}
# Final Test Accuracy: 0.7446
# --------------------
# Training DCN...
# [DCN] Epoch 10/10 | Train Loss: 12.3021 | Val Loss: 6.1656 | Train Acc: 0.6983 | Val Acc: 0.7664 | Val AUC: 0.7771 | Val MCC: 0.3493
# ----------
# Best Val Acc: 0.7664 | Val AUC: 0.7771
# Best Hyperparameters: {'hidden_sizes': [64, 32], 'dropout': 0.2, 'lr': 0.0003, 'weight_decay': 0.01}
# Final Test Accuracy: 0.7650
# --------------------
# Training DCN...
# [DCN] Epoch 10/10 | Train Loss: 32.4836 | Val Loss: 25.6335 | Train Acc: 0.6957 | Val Acc: 0.7343 | Val AUC: 0.7589 | Val MCC: 0.3316
# ----------
# Best Val Acc: 0.7343 | Val AUC: 0.7589
# Best Hyperparameters: {'hidden_sizes': [64, 32], 'dropout': 0.2, 'lr': 0.0001, 'weight_decay': 0.0001}
# Final Test Accuracy: 0.7281
# --------------------
# Training DCN...
# [DCN] Epoch 10/10 | Train Loss: 27.8638 | Val Loss: 19.1064 | Train Acc: 0.6888 | Val Acc: 0.7331 | Val AUC: 0.7588 | Val MCC: 0.3270
# ----------
# Best Val Acc: 0.7331 | Val AUC: 0.7588
# Best Hyperparameters: {'hidden_sizes': [64, 32], 'dropout': 0.2, 'lr': 0.0001, 'weight_decay': 0.001}
# Final Test Accuracy: 0.7281
# --------------------
# Training DCN...
# [DCN] Epoch 10/10 | Train Loss: 24.3255 | Val Loss: 15.9118 | Train Acc: 0.6823 | Val Acc: 0.7404 | Val AUC: 0.7620 | Val MCC: 0.3342
# ----------
# Best Val Acc: 0.7404 | Val AUC: 0.7620
# Best Hyperparameters: {'hidden_sizes': [64, 32], 'dropout': 0.2, 'lr': 0.0001, 'weight_decay': 0.01}
# Final Test Accuracy: 0.7384
# --------------------
# Training DCN...
# [DCN] Epoch 10/10 | Train Loss: 3.6947 | Val Loss: 3.6918 | Train Acc: 0.7170 | Val Acc: 0.7168 | Val AUC: 0.7589 | Val MCC: 0.3001
# ----------
# Best Val Acc: 0.8209 | Val AUC: 0.7410
# Best Hyperparameters: {'hidden_sizes': [128, 64], 'dropout': 0.0, 'lr': 0.001, 'weight_decay': 0.0001}
# Final Test Accuracy: 0.8222
# --------------------
# Training DCN...
# [DCN] Epoch 10/10 | Train Loss: 3.4512 | Val Loss: 2.4055 | Train Acc: 0.7119 | Val Acc: 0.8068 | Val AUC: 0.7511 | Val MCC: 0.3230
# ----------
# Best Val Acc: 0.8068 | Val AUC: 0.7511
# Best Hyperparameters: {'hidden_sizes': [128, 64], 'dropout': 0.0, 'lr': 0.001, 'weight_decay': 0.001}
# Final Test Accuracy: 0.8050
# --------------------
# Training DCN...
# [DCN] Epoch 10/10 | Train Loss: 2.4501 | Val Loss: 2.0148 | Train Acc: 0.7238 | Val Acc: 0.7545 | Val AUC: 0.7547 | Val MCC: 0.2944
# ----------
# Best Val Acc: 0.8104 | Val AUC: 0.7693
# Best Hyperparameters: {'hidden_sizes': [128, 64], 'dropout': 0.0, 'lr': 0.001, 'weight_decay': 0.01}
# Final Test Accuracy: 0.8073
# --------------------
# Training DCN...
# [DCN] Epoch 10/10 | Train Loss: 5.7290 | Val Loss: 5.6932 | Train Acc: 0.6967 | Val Acc: 0.7213 | Val AUC: 0.7305 | Val MCC: 0.2733
# ----------
# Best Val Acc: 0.7213 | Val AUC: 0.7305
# Best Hyperparameters: {'hidden_sizes': [128, 64], 'dropout': 0.0, 'lr': 0.0003, 'weight_decay': 0.0001}
# Final Test Accuracy: 0.7173
# --------------------
# Training DCN...
# [DCN] Epoch 10/10 | Train Loss: 8.2995 | Val Loss: 9.1149 | Train Acc: 0.6928 | Val Acc: 0.6553 | Val AUC: 0.7405 | Val MCC: 0.2610
# ----------
# Best Val Acc: 0.7293 | Val AUC: 0.7370
# Best Hyperparameters: {'hidden_sizes': [128, 64], 'dropout': 0.0, 'lr': 0.0003, 'weight_decay': 0.001}
# Final Test Accuracy: 0.7283
# --------------------
# Training DCN...
# [DCN] Epoch 10/10 | Train Loss: 4.3708 | Val Loss: 5.1988 | Train Acc: 0.7157 | Val Acc: 0.6613 | Val AUC: 0.7528 | Val MCC: 0.2773
# ----------
# Best Val Acc: 0.7473 | Val AUC: 0.7451
# Best Hyperparameters: {'hidden_sizes': [128, 64], 'dropout': 0.0, 'lr': 0.0003, 'weight_decay': 0.01}
# Final Test Accuracy: 0.7380
# --------------------
# Training DCN...
# [DCN] Epoch 10/10 | Train Loss: 16.5537 | Val Loss: 15.9004 | Train Acc: 0.7465 | Val Acc: 0.7414 | Val AUC: 0.7733 | Val MCC: 0.3491
# ----------
# Best Val Acc: 0.7414 | Val AUC: 0.7733
# Best Hyperparameters: {'hidden_sizes': [128, 64], 'dropout': 0.0, 'lr': 0.0001, 'weight_decay': 0.0001}
# Final Test Accuracy: 0.7324
# --------------------
# Training DCN...
# [DCN] Epoch 10/10 | Train Loss: 5.2337 | Val Loss: 5.1608 | Train Acc: 0.6962 | Val Acc: 0.7073 | Val AUC: 0.7279 | Val MCC: 0.2672
# ----------
# Best Val Acc: 0.7267 | Val AUC: 0.7255
# Best Hyperparameters: {'hidden_sizes': [128, 64], 'dropout': 0.0, 'lr': 0.0001, 'weight_decay': 0.001}
# Final Test Accuracy: 0.7235
# --------------------
# Training DCN...
# [DCN] Epoch 10/10 | Train Loss: 11.7410 | Val Loss: 14.9627 | Train Acc: 0.7196 | Val Acc: 0.6639 | Val AUC: 0.7566 | Val MCC: 0.2892
# ----------
# Best Val Acc: 0.7018 | Val AUC: 0.7556
# Best Hyperparameters: {'hidden_sizes': [128, 64], 'dropout': 0.0, 'lr': 0.0001, 'weight_decay': 0.01}
# Final Test Accuracy: 0.7079
# --------------------
# Training DCN...
# [DCN] Epoch 10/10 | Train Loss: 3.7574 | Val Loss: 2.4975 | Train Acc: 0.7030 | Val Acc: 0.7334 | Val AUC: 0.8088 | Val MCC: 0.3637
# ----------
# Best Val Acc: 0.8600 | Val AUC: 0.7916
# Best Hyperparameters: {'hidden_sizes': [128, 64], 'dropout': 0.1, 'lr': 0.001, 'weight_decay': 0.0001}
# Final Test Accuracy: 0.8603
# --------------------
# Training DCN...
# [DCN] Epoch 10/10 | Train Loss: 3.9553 | Val Loss: 2.1103 | Train Acc: 0.7551 | Val Acc: 0.8575 | Val AUC: 0.7633 | Val MCC: 0.3658
# ----------
# Best Val Acc: 0.8575 | Val AUC: 0.7633
# Best Hyperparameters: {'hidden_sizes': [128, 64], 'dropout': 0.1, 'lr': 0.001, 'weight_decay': 0.001}
# Final Test Accuracy: 0.8487
# --------------------
# Training DCN...
# [DCN] Epoch 10/10 | Train Loss: 4.8842 | Val Loss: 3.6714 | Train Acc: 0.6944 | Val Acc: 0.7140 | Val AUC: 0.8098 | Val MCC: 0.3538
# ----------
# Best Val Acc: 0.8297 | Val AUC: 0.7881
# Best Hyperparameters: {'hidden_sizes': [128, 64], 'dropout': 0.1, 'lr': 0.001, 'weight_decay': 0.01}
# Final Test Accuracy: 0.8298
# --------------------
# Training DCN...
# [DCN] Epoch 10/10 | Train Loss: 7.6144 | Val Loss: 4.8645 | Train Acc: 0.7170 | Val Acc: 0.7336 | Val AUC: 0.7829 | Val MCC: 0.3388
# ----------
# Best Val Acc: 0.7336 | Val AUC: 0.7829
# Best Hyperparameters: {'hidden_sizes': [128, 64], 'dropout': 0.1, 'lr': 0.0003, 'weight_decay': 0.0001}
# Final Test Accuracy: 0.7214
# --------------------
# Training DCN...
# [DCN] Epoch 10/10 | Train Loss: 6.2893 | Val Loss: 3.8815 | Train Acc: 0.7155 | Val Acc: 0.7404 | Val AUC: 0.8028 | Val MCC: 0.3554
# ----------
# Best Val Acc: 0.7797 | Val AUC: 0.7985
# Best Hyperparameters: {'hidden_sizes': [128, 64], 'dropout': 0.1, 'lr': 0.0003, 'weight_decay': 0.001}
# Final Test Accuracy: 0.7747
# --------------------
# Training DCN...
# [DCN] Epoch 10/10 | Train Loss: 10.1372 | Val Loss: 6.5298 | Train Acc: 0.6935 | Val Acc: 0.7238 | Val AUC: 0.8033 | Val MCC: 0.3565
# ----------
# Best Val Acc: 0.7238 | Val AUC: 0.8033
# Best Hyperparameters: {'hidden_sizes': [128, 64], 'dropout': 0.1, 'lr': 0.0003, 'weight_decay': 0.01}
# Final Test Accuracy: 0.7109
# --------------------
# Training DCN...
# [DCN] Epoch 10/10 | Train Loss: 24.7838 | Val Loss: 15.5902 | Train Acc: 0.6700 | Val Acc: 0.7308 | Val AUC: 0.7442 | Val MCC: 0.3062
# ----------
# Best Val Acc: 0.7308 | Val AUC: 0.7442
# Best Hyperparameters: {'hidden_sizes': [128, 64], 'dropout': 0.1, 'lr': 0.0001, 'weight_decay': 0.0001}
# Final Test Accuracy: 0.7228
# --------------------
# Training DCN...
# [DCN] Epoch 10/10 | Train Loss: 17.5520 | Val Loss: 12.0789 | Train Acc: 0.6853 | Val Acc: 0.7357 | Val AUC: 0.7812 | Val MCC: 0.3468
# ----------
# Best Val Acc: 0.7357 | Val AUC: 0.7812
# Best Hyperparameters: {'hidden_sizes': [128, 64], 'dropout': 0.1, 'lr': 0.0001, 'weight_decay': 0.001}
# Final Test Accuracy: 0.7266
# --------------------
# Training DCN...
# [DCN] Epoch 10/10 | Train Loss: 19.9176 | Val Loss: 17.4053 | Train Acc: 0.7289 | Val Acc: 0.7435 | Val AUC: 0.7751 | Val MCC: 0.3498
# ----------
# Best Val Acc: 0.7435 | Val AUC: 0.7751
# Best Hyperparameters: {'hidden_sizes': [128, 64], 'dropout': 0.1, 'lr': 0.0001, 'weight_decay': 0.01}
# Final Test Accuracy: 0.7400
# --------------------
# Training DCN...
# [DCN] Epoch 10/10 | Train Loss: 4.6101 | Val Loss: 2.0104 | Train Acc: 0.6945 | Val Acc: 0.7912 | Val AUC: 0.8029 | Val MCC: 0.3734
# ----------
# Best Val Acc: 0.7912 | Val AUC: 0.8029
# Best Hyperparameters: {'hidden_sizes': [128, 64], 'dropout': 0.2, 'lr': 0.001, 'weight_decay': 0.0001}
# Final Test Accuracy: 0.7881
# --------------------
# Training DCN...
# [DCN] Epoch 10/10 | Train Loss: 5.8636 | Val Loss: 3.6286 | Train Acc: 0.7051 | Val Acc: 0.7281 | Val AUC: 0.8121 | Val MCC: 0.3676
# ----------
# Best Val Acc: 0.7971 | Val AUC: 0.8100
# Best Hyperparameters: {'hidden_sizes': [128, 64], 'dropout': 0.2, 'lr': 0.001, 'weight_decay': 0.001}
# Final Test Accuracy: 0.7910
# --------------------
# Training DCN...
# [DCN] Epoch 10/10 | Train Loss: 7.0279 | Val Loss: 5.0572 | Train Acc: 0.7279 | Val Acc: 0.7129 | Val AUC: 0.7906 | Val MCC: 0.3314
# ----------
# Best Val Acc: 0.8179 | Val AUC: 0.7828
# Best Hyperparameters: {'hidden_sizes': [128, 64], 'dropout': 0.2, 'lr': 0.001, 'weight_decay': 0.01}
# Final Test Accuracy: 0.8186
# --------------------
# Training DCN...
# [DCN] Epoch 10/10 | Train Loss: 9.4055 | Val Loss: 5.1104 | Train Acc: 0.7148 | Val Acc: 0.7617 | Val AUC: 0.7811 | Val MCC: 0.3515
# ----------
# Best Val Acc: 0.7617 | Val AUC: 0.7811
# Best Hyperparameters: {'hidden_sizes': [128, 64], 'dropout': 0.2, 'lr': 0.0003, 'weight_decay': 0.0001}
# Final Test Accuracy: 0.7589
# --------------------
# Training DCN...
# [DCN] Epoch 10/10 | Train Loss: 10.1795 | Val Loss: 4.6727 | Train Acc: 0.6903 | Val Acc: 0.7830 | Val AUC: 0.7909 | Val MCC: 0.3719
# ----------
# Best Val Acc: 0.7830 | Val AUC: 0.7909
# Best Hyperparameters: {'hidden_sizes': [128, 64], 'dropout': 0.2, 'lr': 0.0003, 'weight_decay': 0.001}
# Final Test Accuracy: 0.7821
# --------------------
# Training DCN...
# [DCN] Epoch 10/10 | Train Loss: 9.2878 | Val Loss: 5.7952 | Train Acc: 0.7120 | Val Acc: 0.7225 | Val AUC: 0.7930 | Val MCC: 0.3420
# ----------
# Best Val Acc: 0.8099 | Val AUC: 0.7725
# Best Hyperparameters: {'hidden_sizes': [128, 64], 'dropout': 0.2, 'lr': 0.0003, 'weight_decay': 0.01}
# Final Test Accuracy: 0.8092
# --------------------
# Training DCN...
# [DCN] Epoch 10/10 | Train Loss: 19.4155 | Val Loss: 9.5429 | Train Acc: 0.6639 | Val Acc: 0.7489 | Val AUC: 0.7561 | Val MCC: 0.3234
# ----------
# Best Val Acc: 0.7489 | Val AUC: 0.7561
# Best Hyperparameters: {'hidden_sizes': [128, 64], 'dropout': 0.2, 'lr': 0.0001, 'weight_decay': 0.0001}
# Final Test Accuracy: 0.7423
# --------------------
# Training DCN...
# [DCN] Epoch 10/10 | Train Loss: 30.4718 | Val Loss: 18.8081 | Train Acc: 0.6812 | Val Acc: 0.7329 | Val AUC: 0.7495 | Val MCC: 0.3166
# ----------
# Best Val Acc: 0.7329 | Val AUC: 0.7495
# Best Hyperparameters: {'hidden_sizes': [128, 64], 'dropout': 0.2, 'lr': 0.0001, 'weight_decay': 0.001}
# Final Test Accuracy: 0.7241
# --------------------
# Training DCN...
# [DCN] Epoch 10/10 | Train Loss: 28.7000 | Val Loss: 21.1024 | Train Acc: 0.7150 | Val Acc: 0.7483 | Val AUC: 0.7764 | Val MCC: 0.3591
# ----------
# Best Val Acc: 0.7483 | Val AUC: 0.7764
# Best Hyperparameters: {'hidden_sizes': [128, 64], 'dropout': 0.2, 'lr': 0.0001, 'weight_decay': 0.01}
# Final Test Accuracy: 0.7485
# --------------------
# Training DCN...
# [DCN] Epoch 10/10 | Train Loss: 4.0600 | Val Loss: 3.8773 | Train Acc: 0.7012 | Val Acc: 0.6875 | Val AUC: 0.7390 | Val MCC: 0.2694
# ----------
# Best Val Acc: 0.8071 | Val AUC: 0.7356
# Best Hyperparameters: {'hidden_sizes': [32, 16], 'dropout': 0.0, 'lr': 0.001, 'weight_decay': 0.0001}
# Final Test Accuracy: 0.8085
# --------------------
# Training DCN...
# [DCN] Epoch 10/10 | Train Loss: 3.3200 | Val Loss: 3.8010 | Train Acc: 0.7015 | Val Acc: 0.6600 | Val AUC: 0.7362 | Val MCC: 0.2585
# ----------
# Best Val Acc: 0.7640 | Val AUC: 0.7516
# Best Hyperparameters: {'hidden_sizes': [32, 16], 'dropout': 0.0, 'lr': 0.001, 'weight_decay': 0.001}
# Final Test Accuracy: 0.7568
# --------------------
# Training DCN...
# [DCN] Epoch 10/10 | Train Loss: 3.3142 | Val Loss: 3.4529 | Train Acc: 0.7055 | Val Acc: 0.6814 | Val AUC: 0.7536 | Val MCC: 0.2805
# ----------
# Best Val Acc: 0.8267 | Val AUC: 0.7499
# Best Hyperparameters: {'hidden_sizes': [32, 16], 'dropout': 0.0, 'lr': 0.001, 'weight_decay': 0.01}
# Final Test Accuracy: 0.8286
# --------------------
# Training DCN...
# [DCN] Epoch 10/10 | Train Loss: 4.6132 | Val Loss: 5.1229 | Train Acc: 0.6866 | Val Acc: 0.6440 | Val AUC: 0.7270 | Val MCC: 0.2500
# ----------
# Best Val Acc: 0.7308 | Val AUC: 0.7170
# Best Hyperparameters: {'hidden_sizes': [32, 16], 'dropout': 0.0, 'lr': 0.0003, 'weight_decay': 0.0001}
# Final Test Accuracy: 0.7316
# --------------------
# Training DCN...
# [DCN] Epoch 10/10 | Train Loss: 5.3954 | Val Loss: 4.1958 | Train Acc: 0.6946 | Val Acc: 0.7397 | Val AUC: 0.7297 | Val MCC: 0.2754
# ----------
# Best Val Acc: 0.7397 | Val AUC: 0.7297
# Best Hyperparameters: {'hidden_sizes': [32, 16], 'dropout': 0.0, 'lr': 0.0003, 'weight_decay': 0.001}
# Final Test Accuracy: 0.7405
# --------------------
# Training DCN...
# [DCN] Epoch 10/10 | Train Loss: 4.8043 | Val Loss: 5.1042 | Train Acc: 0.6970 | Val Acc: 0.6973 | Val AUC: 0.7291 | Val MCC: 0.2709
# ----------
# Best Val Acc: 0.7180 | Val AUC: 0.7308
# Best Hyperparameters: {'hidden_sizes': [32, 16], 'dropout': 0.0, 'lr': 0.0003, 'weight_decay': 0.01}
# Final Test Accuracy: 0.7145
# --------------------
# Training DCN...
# [DCN] Epoch 10/10 | Train Loss: 22.4595 | Val Loss: 20.0738 | Train Acc: 0.6789 | Val Acc: 0.6910 | Val AUC: 0.6951 | Val MCC: 0.2356
# ----------
# Best Val Acc: 0.6910 | Val AUC: 0.6951
# Best Hyperparameters: {'hidden_sizes': [32, 16], 'dropout': 0.0, 'lr': 0.0001, 'weight_decay': 0.0001}
# Final Test Accuracy: 0.6930
# --------------------
# Training DCN...
# [DCN] Epoch 10/10 | Train Loss: 8.6889 | Val Loss: 8.1863 | Train Acc: 0.7096 | Val Acc: 0.7088 | Val AUC: 0.7478 | Val MCC: 0.2878
# ----------
# Best Val Acc: 0.7088 | Val AUC: 0.7478
# Best Hyperparameters: {'hidden_sizes': [32, 16], 'dropout': 0.0, 'lr': 0.0001, 'weight_decay': 0.001}
# Final Test Accuracy: 0.7013
# --------------------
# Training DCN...
# [DCN] Epoch 10/10 | Train Loss: 26.5247 | Val Loss: 27.0954 | Train Acc: 0.7440 | Val Acc: 0.7360 | Val AUC: 0.7696 | Val MCC: 0.3523
# ----------
# Best Val Acc: 0.7360 | Val AUC: 0.7696
# Best Hyperparameters: {'hidden_sizes': [32, 16], 'dropout': 0.0, 'lr': 0.0001, 'weight_decay': 0.01}
# Final Test Accuracy: 0.7280
# --------------------
# Training DCN...
# [DCN] Epoch 10/10 | Train Loss: 5.7735 | Val Loss: 3.4962 | Train Acc: 0.6973 | Val Acc: 0.7268 | Val AUC: 0.7991 | Val MCC: 0.3555
# ----------
# Best Val Acc: 0.8203 | Val AUC: 0.8040
# Best Hyperparameters: {'hidden_sizes': [32, 16], 'dropout': 0.1, 'lr': 0.001, 'weight_decay': 0.0001}
# Final Test Accuracy: 0.8173
# --------------------
# Training DCN...
# [DCN] Epoch 10/10 | Train Loss: 8.1014 | Val Loss: 5.0031 | Train Acc: 0.6833 | Val Acc: 0.6981 | Val AUC: 0.7976 | Val MCC: 0.3369
# ----------
# Best Val Acc: 0.7552 | Val AUC: 0.8086
# Best Hyperparameters: {'hidden_sizes': [32, 16], 'dropout': 0.1, 'lr': 0.001, 'weight_decay': 0.001}
# Final Test Accuracy: 0.7461
# --------------------
# Training DCN...
# [DCN] Epoch 10/10 | Train Loss: 3.0114 | Val Loss: 2.1961 | Train Acc: 0.6999 | Val Acc: 0.6719 | Val AUC: 0.8017 | Val MCC: 0.3260
# ----------
# Best Val Acc: 0.7738 | Val AUC: 0.8053
# Best Hyperparameters: {'hidden_sizes': [32, 16], 'dropout': 0.1, 'lr': 0.001, 'weight_decay': 0.01}
# Final Test Accuracy: 0.7691
# --------------------
# Training DCN...
# [DCN] Epoch 10/10 | Train Loss: 5.6978 | Val Loss: 3.4114 | Train Acc: 0.7081 | Val Acc: 0.7470 | Val AUC: 0.8056 | Val MCC: 0.3636
# ----------
# Best Val Acc: 0.7470 | Val AUC: 0.8056
# Best Hyperparameters: {'hidden_sizes': [32, 16], 'dropout': 0.1, 'lr': 0.0003, 'weight_decay': 0.0001}
# Final Test Accuracy: 0.7346
# --------------------
# Training DCN...
# [DCN] Epoch 10/10 | Train Loss: 5.7131 | Val Loss: 3.2604 | Train Acc: 0.6977 | Val Acc: 0.7286 | Val AUC: 0.7923 | Val MCC: 0.3405
# ----------
# Best Val Acc: 0.7286 | Val AUC: 0.7923
# Best Hyperparameters: {'hidden_sizes': [32, 16], 'dropout': 0.1, 'lr': 0.0003, 'weight_decay': 0.001}
# Final Test Accuracy: 0.7213
# --------------------
# Training DCN...
# [DCN] Epoch 10/10 | Train Loss: 13.6734 | Val Loss: 8.4034 | Train Acc: 0.6985 | Val Acc: 0.7673 | Val AUC: 0.7788 | Val MCC: 0.3571
# ----------
# Best Val Acc: 0.7673 | Val AUC: 0.7788
# Best Hyperparameters: {'hidden_sizes': [32, 16], 'dropout': 0.1, 'lr': 0.0003, 'weight_decay': 0.01}
# Final Test Accuracy: 0.7620
# --------------------
# Training DCN...
# [DCN] Epoch 10/10 | Train Loss: 30.0060 | Val Loss: 22.1866 | Train Acc: 0.6888 | Val Acc: 0.7255 | Val AUC: 0.7464 | Val MCC: 0.3135
# ----------
# Best Val Acc: 0.7255 | Val AUC: 0.7464
# Best Hyperparameters: {'hidden_sizes': [32, 16], 'dropout': 0.1, 'lr': 0.0001, 'weight_decay': 0.0001}
# Final Test Accuracy: 0.7138
# --------------------
# Training DCN...
# [DCN] Epoch 10/10 | Train Loss: 29.8871 | Val Loss: 22.4112 | Train Acc: 0.6906 | Val Acc: 0.7325 | Val AUC: 0.7628 | Val MCC: 0.3363
# ----------
# Best Val Acc: 0.7325 | Val AUC: 0.7628
# Best Hyperparameters: {'hidden_sizes': [32, 16], 'dropout': 0.1, 'lr': 0.0001, 'weight_decay': 0.001}
# Final Test Accuracy: 0.7271
# --------------------
# Training DCN...
# [DCN] Epoch 10/10 | Train Loss: 32.3035 | Val Loss: 22.3996 | Train Acc: 0.6813 | Val Acc: 0.7207 | Val AUC: 0.7424 | Val MCC: 0.2983
# ----------
# Best Val Acc: 0.7207 | Val AUC: 0.7424
# Best Hyperparameters: {'hidden_sizes': [32, 16], 'dropout': 0.1, 'lr': 0.0001, 'weight_decay': 0.01}
# Final Test Accuracy: 0.7144
# --------------------
# Training DCN...
# [DCN] Epoch 10/10 | Train Loss: 2.2631 | Val Loss: 1.4021 | Train Acc: 0.7013 | Val Acc: 0.7324 | Val AUC: 0.7985 | Val MCC: 0.3452
# ----------
# Best Val Acc: 0.7324 | Val AUC: 0.7985
# Best Hyperparameters: {'hidden_sizes': [32, 16], 'dropout': 0.2, 'lr': 0.001, 'weight_decay': 0.0001}
# Final Test Accuracy: 0.7291
# --------------------
# Training DCN...
# [DCN] Epoch 10/10 | Train Loss: 3.0673 | Val Loss: 1.5826 | Train Acc: 0.7031 | Val Acc: 0.7565 | Val AUC: 0.8100 | Val MCC: 0.3667
# ----------
# Best Val Acc: 0.7565 | Val AUC: 0.8100
# Best Hyperparameters: {'hidden_sizes': [32, 16], 'dropout': 0.2, 'lr': 0.001, 'weight_decay': 0.001}
# Final Test Accuracy: 0.7506
# --------------------
# Training DCN...
# [DCN] Epoch 10/10 | Train Loss: 1.4190 | Val Loss: 0.7262 | Train Acc: 0.7216 | Val Acc: 0.7870 | Val AUC: 0.8154 | Val MCC: 0.3837
# ----------
# Best Val Acc: 0.7870 | Val AUC: 0.8154
# Best Hyperparameters: {'hidden_sizes': [32, 16], 'dropout': 0.2, 'lr': 0.001, 'weight_decay': 0.01}
# Final Test Accuracy: 0.7750
# --------------------
# Training DCN...
# [DCN] Epoch 10/10 | Train Loss: 22.5586 | Val Loss: 12.0560 | Train Acc: 0.6770 | Val Acc: 0.7307 | Val AUC: 0.7479 | Val MCC: 0.3061
# ----------
# Best Val Acc: 0.7307 | Val AUC: 0.7479
# Best Hyperparameters: {'hidden_sizes': [32, 16], 'dropout': 0.2, 'lr': 0.0003, 'weight_decay': 0.0001}
# Final Test Accuracy: 0.7243
# --------------------
# Training DCN...
# [DCN] Epoch 10/10 | Train Loss: 11.5545 | Val Loss: 4.8194 | Train Acc: 0.6902 | Val Acc: 0.7747 | Val AUC: 0.7959 | Val MCC: 0.3761
# ----------
# Best Val Acc: 0.7747 | Val AUC: 0.7959
# Best Hyperparameters: {'hidden_sizes': [32, 16], 'dropout': 0.2, 'lr': 0.0003, 'weight_decay': 0.001}
# Final Test Accuracy: 0.7680
# --------------------
# Training DCN...
# [DCN] Epoch 10/10 | Train Loss: 8.7596 | Val Loss: 4.4436 | Train Acc: 0.7037 | Val Acc: 0.7655 | Val AUC: 0.7903 | Val MCC: 0.3595
# ----------
# Best Val Acc: 0.7655 | Val AUC: 0.7903
# Best Hyperparameters: {'hidden_sizes': [32, 16], 'dropout': 0.2, 'lr': 0.0003, 'weight_decay': 0.01}
# Final Test Accuracy: 0.7627
# --------------------
# Training DCN...
# [DCN] Epoch 10/10 | Train Loss: 48.0604 | Val Loss: 40.1944 | Train Acc: 0.6414 | Val Acc: 0.6623 | Val AUC: 0.6662 | Val MCC: 0.2124
# ----------
# Best Val Acc: 0.6623 | Val AUC: 0.6662
# Best Hyperparameters: {'hidden_sizes': [32, 16], 'dropout': 0.2, 'lr': 0.0001, 'weight_decay': 0.0001}
# Final Test Accuracy: 0.6625
# --------------------
# Training DCN...
# [DCN] Epoch 10/10 | Train Loss: 64.0204 | Val Loss: 48.3940 | Train Acc: 0.6333 | Val Acc: 0.6753 | Val AUC: 0.6666 | Val MCC: 0.2204
# ----------
# Best Val Acc: 0.6753 | Val AUC: 0.6666
# Best Hyperparameters: {'hidden_sizes': [32, 16], 'dropout': 0.2, 'lr': 0.0001, 'weight_decay': 0.001}
# Final Test Accuracy: 0.6713
# --------------------
# Training DCN...
# [DCN] Epoch 10/10 | Train Loss: 67.7803 | Val Loss: 56.3537 | Train Acc: 0.6670 | Val Acc: 0.6924 | Val AUC: 0.6971 | Val MCC: 0.2608
# ----------
# Best Val Acc: 0.6924 | Val AUC: 0.6971
# Best Hyperparameters: {'hidden_sizes': [32, 16], 'dropout': 0.2, 'lr': 0.0001, 'weight_decay': 0.01}
# Final Test Accuracy: 0.6929
# --------------------

# %%
records = []
for r in hyperparameter_tuned_results:
    records.append({
        "Model": r["model_name"],
        "Best Params": r["best_hyperparams"],
        "Validation Accuracy": r["best_val_acc"],
        "Validation AUC": r["best_val_auc"],
        "Test Accuracy": r["test_acc"]   # <-- updated
    })

df_results = pd.DataFrame(records)
df_results = df_results.sort_values(by="Validation Accuracy", ascending=False)
df_results
# Out:
#          Model                                        Best Params  \
# 117        DCN  {'hidden_sizes': [128, 64], 'dropout': 0.1, 'l...
# 29   SimpleMLP  {'hidden_sizes': [128, 64], 'dropout': 0.0, 'l...
# 28   SimpleMLP  {'hidden_sizes': [128, 64], 'dropout': 0.0, 'l...
# 118        DCN  {'hidden_sizes': [128, 64], 'dropout': 0.1, 'l...
# 1    SimpleMLP  {'hidden_sizes': [64, 32], 'dropout': 0.0, 'lr...
# ..         ...                                                ...
# 161        DCN  {'hidden_sizes': [32, 16], 'dropout': 0.2, 'lr...
# 141        DCN  {'hidden_sizes': [32, 16], 'dropout': 0.0, 'lr...
# 84         DCN  {'hidden_sizes': [64, 32], 'dropout': 0.0, 'lr...
# 160        DCN  {'hidden_sizes': [32, 16], 'dropout': 0.2, 'lr...
# 159        DCN  {'hidden_sizes': [32, 16], 'dropout': 0.2, 'lr...
#
#      Validation Accuracy  Validation AUC  Test Accuracy
# 117             0.860034        0.791565       0.860254
# 29              0.858277        0.814328       0.855477
# 28              0.857574        0.804943       0.856109
# 118             0.857504        0.763279       0.848662
# 1               0.853710        0.823641       0.853018
# ..                   ...             ...            ...
# 161             0.692383        0.697081       0.692897
# 141             0.690978        0.695071       0.693037
# 84              0.683952        0.736911       0.681023
# 160             0.675309        0.666564       0.671257
# 159             0.662310        0.666243       0.662545
#
# [162 rows x 5 columns]

# %%
df_results.to_csv("/content/drive/My Drive/Colab Notebooks/data/DL_hyperparameter_tuned_smote.csv", index=False)

# %%
# 2. Convert DataFrame back into a list of dictionaries

df_results = pd.read_csv("/content/drive/My Drive/Colab Notebooks/data/DL_hyperparameter_tuned_smote.csv")
records = df_results.to_dict(orient="records")

# Now `records` has the same format as your original `hyperparameter_tuned_results`
print(records[:3])  # preview the top 3
# Out:
# [{'Model': 'DCN', 'Best Params': "{'hidden_sizes': [128, 64], 'dropout': 0.1, 'lr': 0.001, 'weight_decay': 0.0001}", 'Validation Accuracy': 0.8600337268128162, 'Validation AUC': 0.7915653132394449, 'Test Accuracy': 0.8602543385090986}, {'Model': 'SimpleMLP', 'Best Params': "{'hidden_sizes': [128, 64], 'dropout': 0.0, 'lr': 0.001, 'weight_decay': 0.01}", 'Validation Accuracy': 0.8582771219786397, 'Validation AUC': 0.8143282622126669, 'Test Accuracy': 0.8554767090564181}, {'Model': 'SimpleMLP', 'Best Params': "{'hidden_sizes': [128, 64], 'dropout': 0.0, 'lr': 0.001, 'weight_decay': 0.001}", 'Validation Accuracy': 0.8575744800449691, 'Validation AUC': 0.8049432637391849, 'Test Accuracy': 0.8561090423663318}]

# %%
# Suppose all quick search results are in this list
results = []
for r in records:
    results.append({
        "model_name": r["Model"],
        "best_hyperparams": r["Best Params"],
        "best_val_acc": r["Validation Accuracy"],
        "best_val_auc": r["Validation AUC"],
        "test_acc": r["Test Accuracy"]
    })

# Get best SimpleMLP
best_mlp = max(
    [r for r in results if r["model_name"] == "SimpleMLP"],
    key=lambda x: x["best_val_acc"]
)

# Get best DCN
best_dcn = max(
    [r for r in results if r["model_name"] == "DCN"],
    key=lambda x: x["best_val_acc"]
)

# Print summary
for r in [best_mlp, best_dcn]:
    print(f"Best {r['model_name']}:")
    print("  Hyperparameters:", r["best_hyperparams"])
    print("  Validation Accuracy:", r["best_val_acc"])
    print("  Validation AUC:", r["best_val_auc"])
    print("-"*30)
# Out:
# Best SimpleMLP:
#   Hyperparameters: {'hidden_sizes': [128, 64], 'dropout': 0.0, 'lr': 0.001, 'weight_decay': 0.01}
#   Validation Accuracy: 0.8582771219786397
#   Validation AUC: 0.8143282622126669
# ------------------------------
# Best DCN:
#   Hyperparameters: {'hidden_sizes': [128, 64], 'dropout': 0.1, 'lr': 0.001, 'weight_decay': 0.0001}
#   Validation Accuracy: 0.8600337268128162
#   Validation AUC: 0.7915653132394449
# ------------------------------

# %% [markdown]
# ### Retrain the Best Models Fully

# %%
# --- Best SimpleMLP ---
import ast

for r in results:
    if isinstance(r["best_hyperparams"], str):
        r["best_hyperparams"] = ast.literal_eval(r["best_hyperparams"])

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)

mlp_cfg = best_mlp["best_hyperparams"]
final_mlp = SimpleMLP(
    input_dim=X_train_final.shape[1],
    hidden_sizes=mlp_cfg["hidden_sizes"],
    dropout=mlp_cfg["dropout"]
).to(device)

final_mlp_result = train_model(
    final_mlp,
    train_loader,
    val_loader,
    test_loader,
    epochs=100,             # full training
    lr=mlp_cfg["lr"],
    weight_decay=mlp_cfg["weight_decay"],
    patience=15,
    hyperparams=mlp_cfg
)

# --- Best DCN ---
dcn_cfg = best_dcn["best_hyperparams"]
final_dcn = DCN(
    input_dim=X_train_final.shape[1],
    deep_hidden=dcn_cfg["hidden_sizes"],  # note DCN uses deep_hidden
    dropout=dcn_cfg["dropout"]
).to(device)

final_dcn_result = train_model(
    final_dcn,
    train_loader,
    val_loader,
    test_loader,
    epochs=200,             # maybe longer for DCN
    lr=dcn_cfg["lr"],
    weight_decay=dcn_cfg["weight_decay"],
    patience=20,
    hyperparams=dcn_cfg
)
# Out:
# Using device: cuda
# Training SimpleMLP...
# [SimpleMLP] Epoch 10/100 | Train Loss: 0.2728 | Val Loss: 0.3890 | Train Acc: 0.8827 | Val Acc: 0.8323 | Val AUC: 0.8036 | Val MCC: 0.3515
# [SimpleMLP] Epoch 20/100 | Train Loss: 0.2311 | Val Loss: 0.4232 | Train Acc: 0.9024 | Val Acc: 0.8197 | Val AUC: 0.8005 | Val MCC: 0.3511
# Early stopping at epoch 28
# ----------
# Best Val Acc: 0.8652 | Val AUC: 0.8153
# Best Hyperparameters: {'hidden_sizes': [128, 64], 'dropout': 0.0, 'lr': 0.001, 'weight_decay': 0.01}
# Final Test Accuracy: 0.8613
# --------------------
# Training DCN...
# [DCN] Epoch 10/200 | Train Loss: 5.1220 | Val Loss: 2.7744 | Train Acc: 0.7325 | Val Acc: 0.7927 | Val AUC: 0.7918 | Val MCC: 0.3617
# [DCN] Epoch 20/200 | Train Loss: 3.1157 | Val Loss: 2.7240 | Train Acc: 0.7641 | Val Acc: 0.7475 | Val AUC: 0.7990 | Val MCC: 0.3518
# [DCN] Epoch 30/200 | Train Loss: 1.7980 | Val Loss: 2.0664 | Train Acc: 0.7843 | Val Acc: 0.7306 | Val AUC: 0.7909 | Val MCC: 0.3277
# [DCN] Epoch 40/200 | Train Loss: 0.9871 | Val Loss: 1.7806 | Train Acc: 0.8020 | Val Acc: 0.6240 | Val AUC: 0.7852 | Val MCC: 0.2908
# [DCN] Epoch 50/200 | Train Loss: 0.5570 | Val Loss: 0.5359 | Train Acc: 0.8163 | Val Acc: 0.8146 | Val AUC: 0.8007 | Val MCC: 0.3648
# [DCN] Epoch 60/200 | Train Loss: 0.4041 | Val Loss: 0.4769 | Train Acc: 0.8339 | Val Acc: 0.8113 | Val AUC: 0.8030 | Val MCC: 0.3606
# [DCN] Epoch 70/200 | Train Loss: 0.3734 | Val Loss: 0.4477 | Train Acc: 0.8471 | Val Acc: 0.8199 | Val AUC: 0.7957 | Val MCC: 0.3562
# [DCN] Epoch 80/200 | Train Loss: 0.3353 | Val Loss: 0.5481 | Train Acc: 0.8632 | Val Acc: 0.7783 | Val AUC: 0.7934 | Val MCC: 0.3472
# [DCN] Epoch 90/200 | Train Loss: 0.3049 | Val Loss: 0.4439 | Train Acc: 0.8764 | Val Acc: 0.8376 | Val AUC: 0.7958 | Val MCC: 0.3501
# [DCN] Epoch 100/200 | Train Loss: 0.2896 | Val Loss: 0.4754 | Train Acc: 0.8837 | Val Acc: 0.8591 | Val AUC: 0.7982 | Val MCC: 0.3152
# Early stopping at epoch 103
# ----------
# Best Val Acc: 0.8589 | Val AUC: 0.8068
# Best Hyperparameters: {'hidden_sizes': [128, 64], 'dropout': 0.1, 'lr': 0.001, 'weight_decay': 0.0001}
# Final Test Accuracy: 0.8614
# --------------------

# %%
final_models_results = [final_mlp_result, final_dcn_result]
pd.DataFrame(final_models_results)
# Out:
#                                                model  best_val_acc  \
# 0  SimpleMLP(\n  (model): Sequential(\n    (0): L...      0.865163
# 1  DCN(\n  (cross): CrossLayer()\n  (deep): Seque...      0.858909
#
#    best_val_auc  test_acc  test_mcc  \
# 0      0.815326  0.861308  0.333283
# 1      0.806817  0.861449  0.357266
#
#                                     best_hyperparams
# 0  {'hidden_sizes': [128, 64], 'dropout': 0.0, 'l...
# 1  {'hidden_sizes': [128, 64], 'dropout': 0.1, 'l...

# %%
# Combine fully trained results
final_results = [final_mlp_result, final_dcn_result]

# Pick the best model by validation accuracy (or you could use Val AUC)
best_result = max(final_results, key=lambda x: x["best_val_acc"])

best_model = best_result["model"]

print("Best Model:", best_result.get("model_name", type(best_model).__name__))
print("Best Validation Accuracy:", best_result["best_val_acc"])
print("Best Validation AUC:", best_result["best_val_auc"])
print("Final Test Accuracy:", best_result["test_acc"])
print("Best Hyperparameters:", best_result["best_hyperparams"])
# Out:
# Best Model: SimpleMLP
# Best Validation Accuracy: 0.8651630129286115
# Best Validation AUC: 0.8153263147187957
# Final Test Accuracy: 0.8613082273589545
# Best Hyperparameters: {'hidden_sizes': [128, 64], 'dropout': 0.0, 'lr': 0.001, 'weight_decay': 0.01}

# %% [markdown]
# ## Model Evaluation

# %%
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt

# %%
def get_predictions_and_labels(loader, model, device):
    model.eval()
    all_preds = []
    all_labels = []

    with torch.no_grad():
        for X_batch, y_batch in loader:
            X_batch, y_batch = X_batch.to(device), y_batch.to(device)
            outputs = model(X_batch)
            # Binary classification
            if outputs.shape[1] == 1:
                preds = (torch.sigmoid(outputs) > 0.5).int()

            # Multi-class classification
            else:
                preds = torch.argmax(outputs, dim=1)

            all_preds.append(preds.cpu())
            all_labels.append(y_batch.cpu())

    all_preds = torch.cat(all_preds).numpy()
    all_labels = torch.cat(all_labels).numpy()

    return all_preds, all_labels

# %%
# Make sure best_model is on the same device as your data
best_model = best_model.to(device)

# Evaluate on test set
y_pred, y_true = get_predictions_and_labels(test_loader, best_model, device)

# Confusion matrix
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(6, 4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title("Confusion Matrix for SimpleMLP")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# Classification report
cr = classification_report(y_true, y_pred, digits=4)
print("\nClassification Report:\n", cr)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0     0.5302    0.3094    0.3907      2046
#          1.0     0.8916    0.9540    0.9217     12187
#
#     accuracy                         0.8613     14233
#    macro avg     0.7109    0.6317    0.6562     14233
# weighted avg     0.8397    0.8613    0.8454     14233
